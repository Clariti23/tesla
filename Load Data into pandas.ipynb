# %%
import pandas as pd

# %%
df = pd.read_csv('datasets/TSLA.csv')

# %%
# df

# %%
## Read headers
df.columns

df['Volume']
# Out:
# 0      26547100
# 1      14136600
# 2      10312900
# 3      11968600
# 4       7926500
#          ...
# 248    11698100
# 249     9636500
# 250     7309300
# 251    12254600
# 252     9976900
# Name: Volume, Length: 253, dtype: int64

# %%
for index, row in df.iterrows():
    print(index,row)
# Out:
# 0 Date         2019-05-23
# Open             194.34
# High             199.47
# Low              186.22
# Close            195.49
# Adj Close        195.49
# Volume         26547100
# Name: 0, dtype: object
# 1 Date         2019-05-24
# Open             199.83
# High             199.98
# Low              188.75
# Close            190.63
# Adj Close        190.63
# Volume         14136600
# Name: 1, dtype: object
# 2 Date         2019-05-28
# Open              191.2
# High                195
# Low              187.85
# Close             188.7
# Adj Close         188.7
# Volume         10312900
# Name: 2, dtype: object
# 3 Date         2019-05-29
# Open              187.1
# High             192.39
# Low              185.04
# Close            189.86
# Adj Close        189.86
# Volume         11968600
# Name: 3, dtype: object
# 4 Date         2019-05-30
# Open             188.75
# High             192.26
# Low              187.02
# Close            188.22
# Adj Close        188.22
# ...
